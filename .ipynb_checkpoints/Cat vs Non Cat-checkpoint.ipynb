# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf

# %%
from tensorflow.keras.datasets import cifar10

train, test= cifar10.load_data()

# %%
X_train, y_train = train[0][:40000], train[1][:40000]
X_valid, y_valid = train[0][40000:], train[1][40000:]
X_test, y_test= test[0], test[1]

# %%
#Scaling the 0-255 values down to 0-1
X_train, X_valid, X_test= X_train/255, X_valid/255, X_test/255

# %%
labels = np.array([
    "airplane","automobile","bird","cat",
    "deer","dog","frog","horse","ship","truck"
])

# %%
y_train, y_valid, y_test = (y_train == 3), (y_valid == 3), (y_test == 3) #cat  vs non cat

# %%
fig, axes= plt.subplots(4,10, figsize= (16,5))

indices= np.random.choice(40000, 40, replace= False)

for (i, ax) in zip(indices, axes.ravel()):
    ax.imshow(X_train[i])
    ax.set_title(y_train[i])
    ax.axis("off")

plt.tight_layout()

# %% [markdown]
# We can see clearly some of the cats are impossible to identify.. case in point

# %%
plt.imshow(X_train[indices[-8]])

# %% [markdown]
# Now how is this a cat

# %%
np.unique(y_train, return_counts=True)
# Out:
# (array([False,  True]), array([36016,  3984], dtype=int64))

# %%
from tensorflow.keras.models import load_model

#Let's see what the base model was doing
model = load_model("cifar_dafault_model.keras")

# %%
y_valid_pred= model.predict(X_valid)
y_valid_pred = np.argmax(y_valid_pred, axis=1)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
y_valid_pred= (y_valid_pred == 3)

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_valid, y_valid_pred)
# Out:
# array([[8091,  893],
#        [ 599,  417]], dtype=int64)

# %% [markdown]
# So in our validation set..
# 1) We have 893 Non Cats being Predicted as Cats
# 2) We have 599 Cats not being classified properly
#
#
# Let's improve on this then

# %% [markdown]
# We don't need to use dropout here, because we want the model to specialize and specifically improve on cats.. focus is not on generalization

# %% [markdown]
# Most of the stuff we tried so far kind off failed.. We need to get a 50/50 split in both our trainign and validation set and ultimatey, we gotta modify them

# %%
# cat_classifier = tf.keras.Sequential([ 
#     tf.keras.layers.Flatten(input_shape= [32,32, 3]),
#     tf.keras.layers.Dense(300, activation= "tanh", kernel_initializer="GlorotNormal"), 
#     tf.keras.layers.Dropout(rate = 0.03),
#     tf.keras.layers.Dense(150, activation= "tanh", kernel_initializer="GlorotNormal"), 
#     tf.keras.layers.Dropout(rate = 0.02),
#     tf.keras.layers.Dense(150, activation= "tanh", kernel_initializer="GlorotNormal"), 
#     tf.keras.layers.Dense(80, activation= "tanh", kernel_initializer="GlorotNormal"), 
#     tf.keras.layers.Dense(40, activation= "tanh", kernel_initializer="GlorotNormal"), 
#     tf.keras.layers.Dense(20, activation= "tanh", kernel_initializer="GlorotNormal"), 
#     tf.keras.layers.Dense(10, activation= "tanh", kernel_initializer="GlorotNormal"),
#     tf.keras.layers.Dense(1, activation= "sigmoid"), 
# ])
# Out:
# C:\Users\Taif Al Ghazali\anaconda3\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# cat_classifier.compile(
#     loss= ["binary_crossentropy"], 
#     optimizer= "adam", 
#     metrics= ["accuracy"])

# %%
# history = cat_classifier.fit(X_train, y_train, epochs= 20, 
#                              validation_data=  (X_valid, y_valid), class_weight= {0:1, 1:9})
# Out:
# Epoch 1/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - accuracy: 0.5635 - loss: 1.2357 - val_accuracy: 0.1016 - val_loss: 0.7179
# Epoch 2/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.4828 - loss: 1.2438 - val_accuracy: 0.1016 - val_loss: 0.7083
# Epoch 3/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.3916 - loss: 1.2692 - val_accuracy: 0.1016 - val_loss: 0.7013
# Epoch 4/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.5348 - loss: 1.2395 - val_accuracy: 0.8984 - val_loss: 0.6376
# Epoch 5/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.5789 - loss: 1.2497 - val_accuracy: 0.1016 - val_loss: 0.6973
# Epoch 6/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.4499 - loss: 1.2524 - val_accuracy: 0.1016 - val_loss: 0.7136
# Epoch 7/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.4242 - loss: 1.2595 - val_accuracy: 0.8984 - val_loss: 0.6750
# Epoch 8/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.5450 - loss: 1.2529 - val_accuracy: 0.8984 - val_loss: 0.6645
# Epoch 9/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.5572 - loss: 1.2528 - val_accuracy: 0.8984 - val_loss: 0.6712
# Epoch 10/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.6956 - loss: 1.2448 - val_accuracy: 0.8984 - val_loss: 0.6700
# Epoch 11/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.6683 - loss: 1.2429 - val_accuracy: 0.1016 - val_loss: 0.7470
# Epoch 12/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step - accuracy: 0.4213 - loss: 1.2568 - val_accuracy: 0.8984 - val_loss: 0.6824
# Epoch 13/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step - accuracy: 0.5552 - loss: 1.2514 - val_accuracy: 0.1016 - val_loss: 0.7016
# Epoch 14/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.6981 - loss: 1.2367 - val_accuracy: 0.1016 - val_loss: 0.7011
# Epoch 15/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.5914 - loss: 1.2280 - val_accuracy: 0.1016 - val_loss: 0.7047
# Epoch 16/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.4979 - loss: 1.2468 - val_accuracy: 0.1016 - val_loss: 0.7125
# Epoch 17/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.3199 - loss: 1.2568 - val_accuracy: 0.8984 - val_loss: 0.6661
# Epoch 18/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.7078 - loss: 1.2279 - val_accuracy: 0.1016 - val_loss: 0.6991
# Epoch 19/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step - accuracy: 0.3609 - loss: 1.2630 - val_accuracy: 0.8984 - val_loss: 0.6623
# Epoch 20/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.5152 - loss: 1.2587 - val_accuracy: 0.1016 - val_loss: 0.7007

# %%
# y_pred= cat_classifier.predict(X_valid)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
# print("min:", y_pred.min())
# print("max:", y_pred.max())
# print("mean:", y_pred.mean())
# print("std:", y_pred.std())
# Out:
# min: 0.48014
# max: 0.48014
# mean: 0.4801401
# std: 8.940697e-08

# %%
# print(y_pred[:20].reshape(-1))
# Out:
# [0.48014 0.48014 0.48014 0.48014 0.48014 0.48014 0.48014 0.48014 0.48014
#  0.48014 0.48014 0.48014 0.48014 0.48014 0.48014 0.48014 0.48014 0.48014
#  0.48014 0.48014]

# %%
# print(np.percentile(y_pred, [0, 1, 5, 25, 50, 75, 95, 99, 100]))
# Out:
# [0.48014 0.48014 0.48014 0.48014 0.48014 0.48014 0.48014 0.48014 0.48014]

# %% [markdown]
# So everything's a non cat.. lol.. It's just going from 0.1 to 0.48 to minimize loss.. but it still believes the best way is to call everything a non cat

# %%
# y_valid_pred = (y_pred>=0.5).astype(int)
# confusion_matrix(y_valid, y_valid_pred)
# Out:
# array([[8984,    0],
#        [1016,    0]], dtype=int64)

# %%
X_train.shape
# Out:
# (40000, 32, 32, 3)

# %%
y_train[:, 0]
# Out:
# array([False, False, False, ..., False, False, False])

# %%
(y_train[:, 0] == True).sum()
# Out:
# 3984

# %%
np.where(y_train[:, 0] == True)[0]
# Out:
# array([    9,    17,    21, ..., 39979, 39980, 39989], dtype=int64)

# %%
cat_idx = np.where(y_train[:, 0] == True)[0]
noncat_idx = np.where(y_train[:, 0] == False)[0]

# Randomly select 4,000 non-cat images
np.random.seed(42) 
noncat_idx_subset = np.random.choice(noncat_idx, size=3984, replace=False)
subset_idx = np.concatenate([cat_idx, noncat_idx_subset])

np.random.shuffle(subset_idx)

X_train_b = X_train[subset_idx] 
y_train_b = y_train[subset_idx]

# %%
X_train_b.shape
# Out:
# (7968, 32, 32, 3)

# %%
y_train_b.shape
# Out:
# (7968, 1)

# %% [markdown]
# We have to extract some data from X_valid

# %%
(y_valid == True).sum()
# Out:
# 1016

# %% [markdown]
# I say take 500 cat images more for training.. X_valid will be shortened to only 1000 images.. (500 cats and 500 non cats)

# %%
cat_vidx = np.where(y_valid[:, 0] == True)[0]
noncat_vidx = np.where(y_valid[:, 0] == False)[0]

np.random.seed(42) 
cat_idx_vsub = np.random.choice(cat_vidx, size = 500, replace = False)
noncat_idx_vsub = np.random.choice(noncat_vidx, size=500, replace=False)

subset_vidx = np.concatenate([cat_idx_vsub, noncat_idx_vsub])
np.random.shuffle(subset_vidx)

X_valid_sub = X_valid[subset_vidx]
y_valid_sub = y_valid[subset_vidx]

X_train_b = np.concatenate([X_train_b, X_valid_sub])
y_train_b = np.concatenate([y_train_b, y_valid_sub])

# %%
X_train_b.shape
# Out:
# (8968, 32, 32, 3)

# %%
valid_mask = np.ones(len(X_valid), dtype=bool)
valid_mask[subset_vidx] = False

X_valid = X_valid[valid_mask]
y_valid = y_valid[valid_mask]

# %%
(y_valid == True).sum()
# Out:
# 516

# %%
cat_vdx = np.where(y_valid[:, 0] == True)[0]
noncat_vdx = np.where(y_valid[:, 0] == False)[0]

np.random.seed(42) 
noncat_vdx_vsub = np.random.choice(noncat_vdx, size=516, replace=False)

subset_vdx = np.concatenate([cat_vdx, noncat_vdx_vsub])
np.random.shuffle(subset_vdx)

X_valid = X_valid[subset_vdx]
y_valid = y_valid[subset_vdx]

# %%
X_valid.shape
# Out:
# (1032, 32, 32, 3)

# %%
X_train_b.shape
# Out:
# (8968, 32, 32, 3)

# %%
(y_train_b == True).shape
# Out:
# (8968, 1)

# %% [markdown]
# We'll examine 2 models, one with dropout a bit and one without any form of dropout.. Here we have 50/50 split.. so we can just use accuracy

# %%
y_train_b
# Out:
# array([[ True],
#        [False],
#        [ True],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
(y_train_b == True).sum()
# Out:
# 4484

# %%
X_valid.shape
# Out:
# (1032, 32, 32, 3)

# %%
(y_valid == True).sum()
# Out:
# 516

# %%
cat_biased = tf.keras.Sequential([ 
    tf.keras.layers.Flatten(input_shape= [32,32, 3]),
    tf.keras.layers.Dense(300, activation= "relu", ),
    tf.keras.layers.Dense(150, activation= "relu", ), 
    tf.keras.layers.Dense(80, activation= "relu", ), 
    tf.keras.layers.Dense(40, activation= "relu", ), 
    tf.keras.layers.Dense(20, activation= "relu", ), 
    tf.keras.layers.Dense(10, activation= "relu", ),
    tf.keras.layers.Dense(1, activation= "sigmoid"), 
])
# Out:
# C:\Users\Taif Al Ghazali\anaconda3\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
cat_biased.compile(
    loss= ["binary_crossentropy"], 
    optimizer= "adam", 
    metrics= ["accuracy"])

# %%
history = cat_biased.fit(X_train_b, y_train_b, epochs= 20, 
                             validation_data=  (X_valid, y_valid))
# Out:
# Epoch 1/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5557 - loss: 0.6837 - val_accuracy: 0.6570 - val_loss: 0.6139
# Epoch 2/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6388 - loss: 0.6278 - val_accuracy: 0.6831 - val_loss: 0.5872
# Epoch 3/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6722 - loss: 0.6121 - val_accuracy: 0.6764 - val_loss: 0.6173
# Epoch 4/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6928 - loss: 0.5800 - val_accuracy: 0.6948 - val_loss: 0.5581
# Epoch 5/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7076 - loss: 0.5625 - val_accuracy: 0.7016 - val_loss: 0.5799
# Epoch 6/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7011 - loss: 0.5674 - val_accuracy: 0.6802 - val_loss: 0.5840
# Epoch 7/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7135 - loss: 0.5633 - val_accuracy: 0.7190 - val_loss: 0.5708
# Epoch 8/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7176 - loss: 0.5581 - val_accuracy: 0.7093 - val_loss: 0.5485
# Epoch 9/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7261 - loss: 0.5490 - val_accuracy: 0.7093 - val_loss: 0.5514
# Epoch 10/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7315 - loss: 0.5412 - val_accuracy: 0.7229 - val_loss: 0.5420
# Epoch 11/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7316 - loss: 0.5446 - val_accuracy: 0.7267 - val_loss: 0.5388
# Epoch 12/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7389 - loss: 0.5314 - val_accuracy: 0.7277 - val_loss: 0.5355
# Epoch 13/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7459 - loss: 0.5307 - val_accuracy: 0.7306 - val_loss: 0.5388
# Epoch 14/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7479 - loss: 0.5183 - val_accuracy: 0.7112 - val_loss: 0.5542
# Epoch 15/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7482 - loss: 0.5171 - val_accuracy: 0.7238 - val_loss: 0.5378
# Epoch 16/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7420 - loss: 0.5205 - val_accuracy: 0.7209 - val_loss: 0.5363
# Epoch 17/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7504 - loss: 0.5038 - val_accuracy: 0.7287 - val_loss: 0.5295
# Epoch 18/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7428 - loss: 0.5101 - val_accuracy: 0.7112 - val_loss: 0.5396
# Epoch 19/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7681 - loss: 0.4869 - val_accuracy: 0.7297 - val_loss: 0.5281
# Epoch 20/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7520 - loss: 0.4947 - val_accuracy: 0.7103 - val_loss: 0.5445

# %%
y_biased_pred= cat_biased.predict(X_valid)
# Out:
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
print("min:", y_biased_pred.min())
print("max:", y_biased_pred.max())
print("mean:", y_biased_pred.mean())
print("std:", y_biased_pred.std())
# Out:
# min: 0.000383798
# max: 0.9989458
# mean: 0.55339277
# std: 0.29043478

# %%
print(np.percentile(y_biased_pred, [0, 1, 5, 25, 50, 75, 95, 99, 100]))
# Out:
# [3.83798004e-04 2.32388725e-03 2.24947719e-02 3.19829501e-01
#  6.47113681e-01 7.83901259e-01 9.19338825e-01 9.84495126e-01
#  9.98945773e-01]

# %%
y_valid_pred = (y_biased_pred>=0.5).astype(int)
confusion_matrix(y_valid, y_valid_pred)
# Out:
# array([[291, 225],
#        [ 74, 442]], dtype=int64)

# %%
def build_model(n_layers):
    layer_sizes = [300, 150, 80, 40, 20, 10]

    model = tf.keras.Sequential([
        tf.keras.layers.Flatten(input_shape=(32, 32, 3))
    ])

    for i in range(n_layers):
        model.add(tf.keras.layers.Dense(layer_sizes[i], activation="relu"))

    model.add(tf.keras.layers.Dense(1, activation="sigmoid"))

    model.compile(
        optimizer="adam",
        loss="binary_crossentropy",
        metrics=["accuracy"]
    )

    return model

# %%
results = {}

for n in range(1, 7):
    print(f"\nTraining {n} hidden layers...")

    model = build_model(n)

    history = model.fit(
        X_train_b,
        y_train_b,
        epochs=20,
        batch_size=32,
        validation_data=(X_valid, y_valid),
    )

    results[n] = max(history.history["val_accuracy"])

    print(f"Best validation accuracy: {results[n]:.4f}")
# Out:
# Training 1 hidden layers...
# Epoch 1/20
# C:\Users\Taif Al Ghazali\anaconda3\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.5995 - loss: 0.8244 - val_accuracy: 0.6415 - val_loss: 0.6328
# Epoch 2/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6384 - loss: 0.6335 - val_accuracy: 0.6899 - val_loss: 0.5803
# Epoch 3/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6831 - loss: 0.6003 - val_accuracy: 0.6967 - val_loss: 0.5711
# Epoch 4/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6904 - loss: 0.5933 - val_accuracy: 0.6880 - val_loss: 0.5771
# Epoch 5/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6981 - loss: 0.5748 - val_accuracy: 0.6899 - val_loss: 0.5781
# Epoch 6/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7133 - loss: 0.5737 - val_accuracy: 0.7025 - val_loss: 0.5662
# Epoch 7/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7003 - loss: 0.5732 - val_accuracy: 0.7209 - val_loss: 0.5558
# Epoch 8/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7104 - loss: 0.5676 - val_accuracy: 0.7074 - val_loss: 0.5568
# Epoch 9/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7095 - loss: 0.5664 - val_accuracy: 0.7132 - val_loss: 0.5593
# Epoch 10/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7191 - loss: 0.5460 - val_accuracy: 0.7112 - val_loss: 0.5585
# Epoch 11/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.
# Epoch 7/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7051 - loss: 0.5731 - val_accuracy: 0.7171 - val_loss: 0.5495
# Epoch 8/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7150 - loss: 0.5603 - val_accuracy: 0.7238 - val_loss: 0.5505
# Epoch 9/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7237 - loss: 0.5464 - val_accuracy: 0.7151 - val_loss: 0.5559
# Epoch 10/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7151 - loss: 0.5533 - val_accuracy: 0.7074 - val_loss: 0.5525
# Epoch 11/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7295 - loss: 0.5424 - val_accuracy: 0.7180 - val_loss: 0.5596
# Epoch 12/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7386 - loss: 0.5398 - val_accuracy: 0.7287 - val_loss: 0.5448
# Epoch 13/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7302 - loss: 0.5403 - val_accuracy: 0.7190 - val_loss: 0.5627
# Epoch 14/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7340 - loss: 0.5399 - val_accuracy: 0.6986 - val_loss: 0.5793
# Epoch 15/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7373 - loss: 0.5279 - val_accuracy: 0.7151 - val_loss: 0.5555
# Epoch 16/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7442 - loss: 0.5263 - val_accuracy: 0.7151 - val_loss: 0.5466
# Epoch 17/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7444 - loss: 0.5274 - val_accuracy: 0.7267 - val_loss: 0.5421
# Epoch 18/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7553 - loss: 0.5073 - val_accuracy: 0.6967 - val_loss: 0.5457
# Epoch 19/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7526 - loss: 0.5115 - val_accuracy: 0.7326 - val_loss: 0.5438
# Epoch 20/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7607 - loss: 0.5056 - val_accuracy: 0.7258 - val_loss: 0.5465
# Best validation accuracy: 0.7326
#
# Training 6 hidden layers...
# Epoch 1/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.5731 - loss: 0.6784 - val_accuracy: 0.6609 - val_loss: 0.6155
# Epoch 2/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6424 - loss: 0.6308 - val_accuracy: 0.7016 - val_loss: 0.5987
# Epoch 3/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6774 - loss: 0.6049 - val_accuracy: 0.6618 - val_loss: 0.6052
# Epoch 4/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6941 - loss: 0.5875 - val_accuracy: 0.7171 - val_loss: 0.5829
# Epoch 5/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6991 - loss: 0.5731 - val_accuracy: 0.7151 - val_loss: 0.5505
# Epoch 6/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7028 - loss: 0.5688 - val_accuracy: 0.7180 - val_loss: 0.5458
# Epoch 7/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7096 - loss: 0.5629 - val_accuracy: 0.6686 - val_loss: 0.5931
# Epoch 8/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7212 - loss: 0.5555 - val_accuracy: 0.7190 - val_loss: 0.5410
# Epoch 9/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7303 - loss: 0.5412 - val_accuracy: 0.7171 - val_loss: 0.5968
# Epoch 10/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7259 - loss: 0.5545 - val_accuracy: 0.7287 - val_loss: 0.5461
# Epoch 11/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7420 - loss: 0.5259 - val_accuracy: 0.7229 - val_loss: 0.5371
# Epoch 12/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7382 - loss: 0.5306 - val_accuracy: 0.7481 - val_loss: 0.5261
# Epoch 13/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7394 - loss: 0.5300 - val_accuracy: 0.6909 - val_loss: 0.5640
# Epoch 14/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7443 - loss: 0.5217 - val_accuracy: 0.7064 - val_loss: 0.5733
# Epoch 15/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7477 - loss: 0.5102 - val_accuracy: 0.7035 - val_loss: 0.5717
# Epoch 16/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7499 - loss: 0.5039 - val_accuracy: 0.7006 - val_loss: 0.5437
# Epoch 17/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7564 - loss: 0.5019 - val_accuracy: 0.7393 - val_loss: 0.5520
# Epoch 18/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7560 - loss: 0.4942 - val_accuracy: 0.7267 - val_loss: 0.5512
# Epoch 19/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7546 - loss: 0.4999 - val_accuracy: 0.7510 - val_loss: 0.5285
# Epoch 20/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7612 - loss: 0.4887 - val_accuracy: 0.7422 - val_loss: 0.5551
# Best validation accuracy: 0.7510

# %% [markdown]
# Yeah so 6 hidden layers is good enough for this

# %%
cat_biased = tf.keras.Sequential([ 
    tf.keras.layers.Flatten(input_shape= [32,32, 3]),
    tf.keras.layers.Dense(300, activation= "relu", ),
    tf.keras.layers.Dense(150, activation= "relu", ), 
    tf.keras.layers.Dense(80, activation= "relu", ), 
    tf.keras.layers.Dense(40, activation= "relu", ), 
    tf.keras.layers.Dense(20, activation= "relu", ), 
    tf.keras.layers.Dense(10, activation= "relu", ),
    tf.keras.layers.Dense(1, activation= "sigmoid"), 
])
# Out:
# C:\Users\Taif Al Ghazali\anaconda3\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor="val_accuracy",
    mode="max",
    patience=8,
    restore_best_weights=True
)

# %%
cat_biased.compile(
    loss= ["binary_crossentropy"], 
    optimizer= "adam", 
    metrics= ["accuracy"])

# %%
history = cat_biased.fit(
    X_train_b,
    y_train_b,
    epochs= 50,
    validation_data=(X_valid, y_valid),
    callbacks=[early_stop]
)
# Out:
# Epoch 1/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.5559 - loss: 0.6911 - val_accuracy: 0.6667 - val_loss: 0.6149
# Epoch 2/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6339 - loss: 0.6360 - val_accuracy: 0.6831 - val_loss: 0.5828
# Epoch 3/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6578 - loss: 0.6179 - val_accuracy: 0.6986 - val_loss: 0.5693
# Epoch 4/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6716 - loss: 0.6033 - val_accuracy: 0.7074 - val_loss: 0.5694
# Epoch 5/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7058 - loss: 0.5674 - val_accuracy: 0.7151 - val_loss: 0.5750
# Epoch 6/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7183 - loss: 0.5674 - val_accuracy: 0.7238 - val_loss: 0.5485
# Epoch 7/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7109 - loss: 0.5576 - val_accuracy: 0.7171 - val_loss: 0.5697
# Epoch 8/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7106 - loss: 0.5570 - val_accuracy: 0.7345 - val_loss: 0.5440
# Epoch 9/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7197 - loss: 0.5527 - val_accuracy: 0.7112 - val_loss: 0.5563
# Epoch 10/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7236 - loss: 0.5377 - val_accuracy: 0.7025 - val_loss: 0.6021
# Epoch 11/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7254 - loss: 0.5442 - val_accuracy: 0.7229 - val_loss: 0.5362
# Epoch 12/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7457 - loss: 0.5202 - val_accuracy: 0.7161 - val_loss: 0.5578
# Epoch 13/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7260 - loss: 0.5354 - val_accuracy: 0.7316 - val_loss: 0.5340
# Epoch 14/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7400 - loss: 0.5211 - val_accuracy: 0.7258 - val_loss: 0.5475
# Epoch 15/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7488 - loss: 0.5221 - val_accuracy: 0.7238 - val_loss: 0.5348
# Epoch 16/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.7345 - loss: 0.5311 - val_accuracy: 0.7064 - val_loss: 0.5627

# %%
y_biased_pred= cat_biased.predict(X_valid)
# Out:
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
y_valid_pred = (y_biased_pred>=0.5).astype(int)
confusion_matrix(y_valid, y_valid_pred)
# Out:
# array([[346, 170],
#        [104, 412]], dtype=int64)

# %% [markdown]
# Let's just compare this with our base model on CIFAR on the test set

# %%
y_cat_pred= cat_biased.predict(X_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
y_cat_pred = (y_cat_pred>=0.5).astype(int)
confusion_matrix(y_test, y_cat_pred)
# Out:
# array([[5944, 3056],
#        [ 226,  774]], dtype=int64)

# %%
from tensorflow.keras.models import load_model

#Let's see what the base model was doing
model = load_model("cifar_dafault_model.keras")

# %%
y_test_pred= model.predict(X_test)
y_model = np.argmax(y_test_pred, axis=1)
y_model=  (y_model ==3)

confusion_matrix(y_test, y_model)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# array([[8057,  943],
#        [ 570,  430]], dtype=int64)

# %% [markdown]
# So we're better on Cats.. clearly... but non cats get a bit messed uup.. We don't really mind that though.. that was the job of the CIFAR model on the other notebook.. In here, we wanted to focus that we can get our Cats identified properly.. and we have succeeded.

# %% [markdown]
# Now, we'll use this model as our base to train the CIFAR-10 model.. that would clean out the non cat issues and give us a better model overall
